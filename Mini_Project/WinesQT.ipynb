# %% [markdown]
# # <u>Project</u>
# ## <u>Project Name : Wine quality prediction</u>

# %% [markdown]
# ## 1.Data collection:
# ### Import Libraries and Load DataSet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/dell/Downloads/DATA SETS/WineQT.csv')
print(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1138 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1142 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1140 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# ## 2.Data Analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1138.000000  1143.000000     1143.000000
# mean        8.311111          0.531388     0.268364        2.532152
# std         1.747595          0.179775     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.396250     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1142.000000           1143.000000  1140.000000
# mean      0.086933            15.614273             45.914698     0.996728
# std       0.047267            10.254895             32.782130     0.001927
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995567
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997842
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8               NaN         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0      NaN  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                  NaN                  60.0      NaN  3.16       0.58
# 4                 11.0                  34.0      NaN  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 15.0                  65.0   0.9959  3.28       0.54
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4
# 5      9.4        5   5
# 6      9.4        5   6
# 7     10.0        7   7
# 8      9.5        7   8
# 9      9.2        5  10

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1133            6.7             0.320         0.44             2.4      0.061
# 1134            7.5             0.310         0.41             2.4      0.065
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1133                 24.0                  34.0  0.99484  3.29       0.80
# 1134                 34.0                  60.0  0.99492  3.34       0.85
# 1135                 18.0                  28.0  0.99483  3.55       0.66
# 1136                 26.0                  35.0  0.99314  3.32       0.82
# 1137                 16.0                  26.0  0.99402  3.67       0.56
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1133     11.6        7  1584
# 1134     11.4        6  1586
# 1135     10.9        6  1587
# 1136     11.6        6  1590
# 1137     11.6        6  1591
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        5
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 3
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %% [markdown]
# ### Aggregaion functions

# %%
df['quality'].mean()
# Out:
# 5.657042869641295

# %%
df['quality'].median()
# Out:
# 6.0

# %%
df['quality'].mode()
# Out:
# 0    5
# Name: quality, dtype: int64

# %%
df['residual sugar'].max()
# Out:
# 15.5

# %%
df['fixed acidity'].std()
# Out:
# 1.747595017169539

# %%
df['total sulfur dioxide'].sum()
# Out:
# 52480.5

# %%
df['chlorides'].agg(['mean','median','max','min','std','sum'])
# Out:
# mean       0.086933
# median     0.079000
# max        0.611000
# min        0.012000
# std        0.047267
# sum       99.364000
# Name: chlorides, dtype: float64

# %%
d=df['residual sugar']+df['chlorides']
d
# Out:
# 0       1.976
# 1       2.698
# 2       2.392
# 3       1.975
# 4       1.976
#         ...
# 1138    2.376
# 1139    1.968
# 1140    2.090
# 1141    2.262
# 1142    2.075
# Length: 1143, dtype: float64

# %%
df['chlorides']=(list(map(lambda x:x+1,df['chlorides'])))
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      1.076
# 1               7.8             0.880         0.00             2.6      1.098
# 2               7.8             0.760         0.04             2.3      1.092
# 3              11.2             0.280         0.56             1.9      1.075
# 4               7.4             0.700         0.00             1.9      1.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      1.076
# 1139            6.8             0.620         0.08             1.9      1.068
# 1140            6.2             0.600         0.08             2.0      1.090
# 1141            5.9             0.550         0.10             2.2      1.062
# 1142            5.9             0.645         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df['quality'] = df['quality'][df['quality'] > 4]
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      1.076
# 1               7.8             0.880         0.00             2.6      1.098
# 2               7.8             0.760         0.04             2.3      1.092
# 3              11.2             0.280         0.56             1.9      1.075
# 4               7.4             0.700         0.00             1.9      1.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      1.076
# 1139            6.8             0.620         0.08             1.9      1.068
# 1140            6.2             0.600         0.08             2.0      1.090
# 1141            5.9             0.550         0.10             2.2      1.062
# 1142            5.9             0.645         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4      5.0     0
# 1         9.8      5.0     1
# 2         9.8      5.0     2
# 3         9.8      6.0     3
# 4         9.4      5.0     4
# ...       ...      ...   ...
# 1138     11.0      6.0  1592
# 1139      9.5      6.0  1593
# 1140     10.5      5.0  1594
# 1141     11.2      6.0  1595
# 1142     10.2      5.0  1597
#
# [1143 rows x 13 columns]

# %%
from functools import reduce
r=reduce(lambda x,y: x+y,df['Id'])
r
# Out:
# 920080

# %% [markdown]
# ## 3.Data Preprocesing and cleaning

# %%
#preprocesing
# adding column
df['total_acidity']=df['fixed acidity']+df['volatile acidity']+df['citric acid']
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      1.076
# 1               7.8             0.880         0.00             2.6      1.098
# 2               7.8             0.760         0.04             2.3      1.092
# 3              11.2             0.280         0.56             1.9      1.075
# 4               7.4             0.700         0.00             1.9      1.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      1.076
# 1139            6.8             0.620         0.08             1.9      1.068
# 1140            6.2             0.600         0.08             2.0      1.090
# 1141            5.9             0.550         0.10             2.2      1.062
# 1142            5.9             0.645         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id  total_acidity
# 0         9.4      5.0     0          8.100
# 1         9.8      5.0     1          8.680
# 2         9.8      5.0     2          8.600
# 3         9.8      6.0     3         12.040
# 4         9.4      5.0     4          8.100
# ...       ...      ...   ...            ...
# 1138     11.0      6.0  1592          6.940
# 1139      9.5      6.0  1593          7.500
# 1140     10.5      5.0  1594          6.880
# 1141     11.2      6.0  1595          6.550
# 1142     10.2      5.0  1597          6.665
#
# [1143 rows x 14 columns]

# %%
df['lable quality']=df['quality'].apply(lambda x:'Low' if x<=3 else ('Medium' if x<=6 else 'High')) 
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      1.076
# 1               7.8             0.880         0.00             2.6      1.098
# 2               7.8             0.760         0.04             2.3      1.092
# 3              11.2             0.280         0.56             1.9      1.075
# 4               7.4             0.700         0.00             1.9      1.076
# ...             ...               ...          ...             ...        ...
# 1139            6.8             0.620         0.08             1.9      1.068
# 1140            6.2             0.600         0.08             2.0      1.090
# 1141            5.9             0.550         0.10             2.2      1.062
# 1142            5.9             0.645         0.12             2.0      1.075
# 1143            5.9             0.645         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
# 1143                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality      Id lable quality
# 0         9.4      5.0     0.0        Medium
# 1         9.8      5.0     1.0        Medium
# 2         9.8      5.0     2.0        Medium
# 3         9.8      6.0     3.0        Medium
# 4         9.4      5.0     4.0        Medium
# ...       ...      ...     ...           ...
# 1139      9.5      6.0  1593.0        Medium
# 1140     10.5      5.0  1594.0        Medium
# 1141     11.2      6.0  1595.0        Medium
# 1142     10.2      5.0  1597.0        Medium
# 1143     10.2      5.0  1597.0        Medium
#
# [1144 rows x 14 columns]

# %%
# adding row
df.loc[len(df)]=[5.9,0.645,0.12,2.0,1.075,32.0,44.0,0.99547,3.57,0.71,10.2,5.0,1597,6.665]
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      1.076
# 1               7.8             0.880         0.00             2.6      1.098
# 2               7.8             0.760         0.04             2.3      1.092
# 3              11.2             0.280         0.56             1.9      1.075
# 4               7.4             0.700         0.00             1.9      1.076
# ...             ...               ...          ...             ...        ...
# 1140            6.2             0.600         0.08             2.0      1.090
# 1141            5.9             0.550         0.10             2.2      1.062
# 1142            5.9             0.645         0.12             2.0      1.075
# 1143            5.9             0.645         0.12             2.0      1.075
# 1144            5.9             0.645         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
# 1143                 32.0                  44.0  0.99547  3.57       0.71
# 1144                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality      Id lable quality
# 0         9.4      5.0     0.0        Medium
# 1         9.8      5.0     1.0        Medium
# 2         9.8      5.0     2.0        Medium
# 3         9.8      6.0     3.0        Medium
# 4         9.4      5.0     4.0        Medium
# ...       ...      ...     ...           ...
# 1140     10.5      5.0  1594.0        Medium
# 1141     11.2      6.0  1595.0        Medium
# 1142     10.2      5.0  1597.0        Medium
# 1143     10.2      5.0  1597.0        Medium
# 1144     10.2      5.0  1597.0         6.665
#
# [1145 rows x 14 columns]

# %%
# droping volatile acidity column
df=df.drop('volatile acidity',axis=1)
df
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      1.076
# 1               7.8         0.00             2.6      1.098
# 2               7.8         0.04             2.3      1.092
# 3              11.2         0.56             1.9      1.075
# 4               7.4         0.00             1.9      1.076
# ...             ...          ...             ...        ...
# 1140            6.2         0.08             2.0      1.090
# 1141            5.9         0.10             2.2      1.062
# 1142            5.9         0.12             2.0      1.075
# 1143            5.9         0.12             2.0      1.075
# 1144            5.9         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0      NaN  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                     NaN                  60.0      NaN  3.16       0.58
# 4                    11.0                  34.0      NaN  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
# 1143                 32.0                  44.0  0.99547  3.57       0.71
# 1144                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality      Id lable quality
# 0         9.4      5.0     0.0        Medium
# 1         9.8      5.0     1.0        Medium
# 2         9.8      5.0     2.0        Medium
# 3         9.8      6.0     3.0        Medium
# 4         9.4      5.0     4.0        Medium
# ...       ...      ...     ...           ...
# 1140     10.5      5.0  1594.0        Medium
# 1141     11.2      6.0  1595.0        Medium
# 1142     10.2      5.0  1597.0        Medium
# 1143     10.2      5.0  1597.0        Medium
# 1144     10.2      5.0  1597.0         6.665
#
# [1145 rows x 13 columns]

# %%
# droping null values
df.dropna()
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      1.076
# 2               7.8         0.04             2.3      1.092
# 5               7.4         0.00             1.8      1.075
# 6               7.9         0.06             1.6      1.069
# 7               7.3         0.00             1.2      1.065
# ...             ...          ...             ...        ...
# 1140            6.2         0.08             2.0      1.090
# 1141            5.9         0.10             2.2      1.062
# 1142            5.9         0.12             2.0      1.075
# 1143            5.9         0.12             2.0      1.075
# 1144            5.9         0.12             2.0      1.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# ...                   ...                   ...      ...   ...        ...
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
# 1143                 32.0                  44.0  0.99547  3.57       0.71
# 1144                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality      Id lable quality
# 0         9.4      5.0     0.0        Medium
# 2         9.8      5.0     2.0        Medium
# 5         9.4      5.0     5.0        Medium
# 6         9.4      5.0     6.0        Medium
# 7        10.0      7.0     7.0          High
# ...       ...      ...     ...           ...
# 1140     10.5      5.0  1594.0        Medium
# 1141     11.2      6.0  1595.0        Medium
# 1142     10.2      5.0  1597.0        Medium
# 1143     10.2      5.0  1597.0        Medium
# 1144     10.2      5.0  1597.0         6.665
#
# [1103 rows x 13 columns]

# %%
# value counts
a=df[['alcohol','residual sugar']].value_counts()
a
# Out:
# alcohol  residual sugar
# 9.5      1.8               12
# 9.4      2.0               11
# 9.5      2.1               10
#          1.9               10
# 9.8      2.2               10
#                            ..
# 10.5     1.6                1
# 10.4     5.1                1
#          3.1                1
#          3.0                1
# 14.9     7.5                1
# Name: count, Length: 548, dtype: int64

# %%
counts=df['quality'].value_counts()
counts
# Out:
# quality
# 5.0    485
# 6.0    462
# 7.0    143
# 8.0     16
# Name: count, dtype: int64

# %%
# cleaning
df.isnull().sum()
# Out:
# fixed acidity            0
# citric acid              0
# residual sugar           0
# chlorides                0
# free sulfur dioxide      1
# total sulfur dioxide     0
# density                  3
# pH                       0
# sulphates                0
# alcohol                  0
# quality                 39
# Id                       0
# lable quality            0
# dtype: int64

# %%
mean=df['quality'].mean()
df['quality']=df['quality'].fillna(mean)
df.isnull().sum()
# Out:
# fixed acidity           0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 3
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# lable quality           0
# dtype: int64

# %%
median=df['free sulfur dioxide'].median()
df['free sulfur dioxide']=df['free sulfur dioxide'].fillna(median)
df.isnull().sum()
# Out:
# fixed acidity           0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 3
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# lable quality           0
# dtype: int64

# %%
mode=df['density'].mode()
df['density']=df['density'].fillna(df['density'].mode()[0])
df.isnull().sum()
# Out:
# fixed acidity           0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# lable quality           0
# dtype: int64

# %%
#handling outliers
plt.boxplot(df['fixed acidity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f83d172d20>,
#   <matplotlib.lines.Line2D at 0x1f83d173260>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f83d173500>,
#   <matplotlib.lines.Line2D at 0x1f83d173980>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f83d172ea0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f83d173ec0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f83d173d70>],
#  'means': []}

# %%
Q1=df['fixed acidity'].quantile(0.25)
Q3=df['fixed acidity'].quantile(0.75)
iqr=Q3-Q1
lower_bound=Q1-1.5*iqr
upper_bound=Q3+1.5*iqr

fare_arr=df['fixed acidity']
lower_cap=0
upper_cap=10
for i in df['fixed acidity']:
    if i < lower_bound:
        df['fixed acidity']=df['fixed acidity'].replace(i,lower_cap)
    elif i > upper_bound:
        df['fixed acidity']=df['fixed acidity'].replace(i,upper_cap)
df['fixed acidity'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['pH'].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1=df['pH'].quantile(0.25)
Q3=df['pH'].quantile(0.75)
iqr=Q3-Q1
lower_bound=Q1-1.5*iqr
upper_bound=Q3+1.5*iqr
df_no_outliers = df[(df['pH'] >= lower_bound) & (df['pH'] <= upper_bound)]
# Optional: plot the cleaned data
df_no_outliers['pH'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## 4.Data visuvalization

# %%
#Alcohol quality count
counts.plot(kind='bar')
plt.title('Alcohol quality')
plt.xlabel('quality')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
b=df[['quality','lable quality']].value_counts().unstack()
b.plot(kind='bar')
# Out:
# <Axes: xlabel='quality'>

# %%
c=(df['chlorides'].value_counts())
c.plot(kind='hist')
plt.xlabel('chlorides')
# Out:
# Text(0.5, 0, 'chlorides')

# %%
plt.scatter(df['alcohol'],df['residual sugar'])
plt.title("Alcohol V/S residual sugar")
plt.xlabel('Alcohol')
plt.ylabel('residual sugar')
# Out:
# Text(0, 0.5, 'residual sugar')

# %%
plt.boxplot(df['pH'])
plt.ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %%
data=df.groupby('quality')['alcohol'].mean()
data.plot(kind='line',marker='o')
plt.xlabel('quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
b=df[['quality','lable quality']].value_counts().unstack()
b.plot(kind='line')
# Out:
# <Axes: xlabel='quality'>

# %%
data=(df['quality'].value_counts())
data.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #
